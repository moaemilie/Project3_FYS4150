# %% [markdown]
# # Project 3

# %% [markdown]
# ### Task 8

# %% [markdown]
# ## Euler in z direction

# %%
import matplotlib.pyplot as plt
  
z_par1_eul = []
z_par2_eul = []
for line in open('Particle_z_Euler.txt', 'r'):
    lines = [i for i in line.split()]
    z_par1_eul.append(float(lines[0]))
    z_par2_eul.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision [z]', fontsize=15)
plt.plot(z_par1_eul)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision [z]', fontsize=15)
plt.plot(z_par2_eul)
  
plt.show()

# %% [markdown]
# ## RK4 in z direction

# %%
import matplotlib.pyplot as plt
  
z_par1_RK = []
z_par2_RK = []
for line in open('Particle_z_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    z_par1_RK.append(float(lines[0]))
    z_par2_RK.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posisjon [z]', fontsize=15)
plt.plot(z_par1_RK)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posisjon [z]', fontsize=15)
plt.plot(z_par2_RK)
  
plt.show()

# %% [markdown]
# ## Euler in xy-plane

# %%
x_par1_eul = []
x_par2_eul = []
for line in open('Particle_x_Euler.txt', 'r'):
    lines = [i for i in line.split()]
    x_par1_eul.append(float(lines[0]))
    x_par2_eul.append(float(lines[1]))

# %%
y_par1_eul = []
y_par2_eul = []
for line in open('Particle_y_Euler.txt', 'r'):
    lines = [i for i in line.split()]
    y_par1_eul.append(float(lines[0]))
    y_par2_eul.append(float(lines[1]))

# %%
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(x_par1_eul, y_par1_eul)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(x_par2_eul, y_par2_eul)
  
plt.show()

# %% [markdown]
# ## RK4 in the xy plane

# %% [markdown]
# ### With interaction

# %%
x_par1_RK = []
x_par2_RK = []
for line in open('Particle_x_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    x_par1_RK.append(float(lines[0]))
    x_par2_RK.append(float(lines[1]))

# %%
y_par1_RK = []
y_par2_RK = []
for line in open('Particle_y_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    y_par1_RK.append(float(lines[0]))
    y_par2_RK.append(float(lines[1]))

# %%
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(x_par1_RK, y_par1_RK)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(x_par2_RK, y_par2_RK)
  
plt.show()

# %% [markdown]
# ### Without interaction

# %%
x_par1_RK_NO = []
x_par2_RK_NO = []
for line in open('Particle_x_RK4_NO.txt', 'r'):
    lines = [i for i in line.split()]
    x_par1_RK_NO.append(float(lines[0]))
    x_par2_RK_NO.append(float(lines[1]))

# %%
y_par1_RK_NO = []
y_par2_RK_NO = []
for line in open('Particle_y_RK4_NO.txt', 'r'):
    lines = [i for i in line.split()]
    y_par1_RK_NO.append(float(lines[0]))
    y_par2_RK_NO.append(float(lines[1]))

# %% [markdown]
# Particle 1

# %%
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(x_par1_RK_NO, y_par1_RK_NO)
  
plt.show()

# %% [markdown]
# Particle 2

# %%
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(x_par2_RK_NO, x_par2_RK_NO)
  
plt.show()

# %% [markdown]
# ## 3D plot

# %% [markdown]
# With interaction

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(x_par1_RK, y_par1_RK, z_par1_RK, 'gray')

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(x_par2_RK, y_par2_RK, z_par2_RK, 'gray')

# %% [markdown]
# Wothout interaction

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(x_par1_RK_NO, y_par1_RK_NO, z_par1_RK_NO, 'gray')

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(x_par2_RK_NO, y_par2_RK_NO, z_par2_RK_NO, 'gray')

# %% [markdown]
# ## Analytical solution

# %%
import matplotlib.pyplot as plt

x_analy = []
y_analy = []
z_analy = []
for line in open('Analytical_SingleParticle.txt', 'r'):
    lines = [i for i in line.split()]
    x_analy.append(float(lines[0]))
    y_analy.append(float(lines[1]))
    z_analy.append(float(lines[1]))

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')

ax.plot3D(x_analy, y_analy, z_analy, 'gray')

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.axis('equal')
plt.plot(x_analy, y_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [z]', fontsize=15)
plt.axis('equal')
plt.plot(x_analy, z_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.axis('equal')
plt.plot(y_analy, z_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision [x]', fontsize=15)
plt.plot(x_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(y_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision [z]', fontsize=15)
plt.plot(z_analy)
  
plt.show()
