# %% [markdown]
# # Project 3

# %% [markdown]
# ### Task 8

# %% [markdown]
# ## RK4 in z direction

# %% [markdown]
# Single particle

# %%
import matplotlib.pyplot as plt

x = []
y = []
z = []
for line in open('Particle_z_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    x.append(float(lines[0]))
    y.append(float(lines[1]))
    z.append(float(lines[2]))

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.set_title('One Particles movement in 50μs', fontsize=15);
ax.set_xlabel('Posision [x]', fontsize=15)
ax.set_ylabel('Posision [y]', fontsize=15)
ax.set_zlabel('Posision [z]', fontsize=15)
ax.plot3D(x, y, z, 'gray')
plt.savefig('figure5.pdf')

# %%
import numpy as np
time = np.linspace(0.0, 50.0, num=501)

fig = plt.figure(figsize=(8, 6))
plt.title('One Particle', fontsize=15)
plt.xlabel('time [μs]', fontsize=15)
plt.ylabel('posision [z]', fontsize=15)
plt.plot(time[0:500], z)
plt.savefig('figure.pdf')
plt.show()

# %% [markdown]
# ## RK4 in the xy plane

# %% [markdown]
# ### With interaction

# %%
part1_x = []
part1_y = []
part2_x = []
part2_y = []
for line in open('2Particle_RK4_INTER.txt', 'r'):
    lines = [i for i in line.split()]
    part1_x.append(float(lines[0]))
    part1_y.append(float(lines[1]))
    part2_x.append(float(lines[2]))
    part2_y.append(float(lines[3]))

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 1, with interaction', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(part1_x, part1_y)
plt.savefig('Particle1_XY_INT.pdf')
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 2, with interaction', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(part2_x, part2_y)
plt.savefig('Particle2_XY_INT.pdf')
plt.show()

# %% [markdown]
# ### Without interaction

# %%
part1_x = []
part1_y = []
part2_x = []
part2_y = []
for line in open('2Particle_RK4_NO_INTER.txt', 'r'):
    lines = [i for i in line.split()]
    part1_x.append(float(lines[0]))
    part1_y.append(float(lines[1]))
    part2_x.append(float(lines[2]))
    part2_y.append(float(lines[3]))

# %% [markdown]
# Particle 1

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 1, without interaction', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(part1_x, part1_y)
plt.savefig('Particle1_XY_NO_INT.pdf')
plt.show()

# %% [markdown]
# Particle 2

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 2, without interaction', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(part2_x, part2_y)
plt.savefig('Particle2_XY_NO_INT.pdf')
plt.show()

# %% [markdown]
# ### plots of the trajectories

# %% [markdown]
# ### With interaction

# %% [markdown]
# Particle 1

# %%
part1_x = []
part1_v_x = []
part1_y = []
part1_v_y = []
for line in open('Particle1_RK4_INTER_speed.txt', 'r'):
    lines = [i for i in line.split()]
    part1_x.append(float(lines[0]))
    part1_v_x.append(float(lines[1]))
    part1_y.append(float(lines[2]))
    part1_v_y.append(float(lines[3]))

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 1, with interaction', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('Speed in x direction', fontsize=15)
plt.plot(part1_x, part1_v_x)
plt.savefig('Particle1_x_speed.pdf')
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 1, with interaction', fontsize=15)
plt.xlabel('position [y]', fontsize=15)
plt.ylabel('Speed in y direction', fontsize=15)
plt.plot(part1_y, part1_v_y)
plt.savefig('Particle1_y_speed.pdf')
plt.show()

# %% [markdown]
# Particle 2

# %%
part2_x = []
part2_v_x = []
part2_y = []
part2_v_y = []
for line in open('Particle2_RK4_INTER_speed.txt', 'r'):
    lines = [i for i in line.split()]
    part2_x.append(float(lines[0]))
    part2_v_x.append(float(lines[1]))
    part2_y.append(float(lines[2]))
    part2_v_y.append(float(lines[3]))

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 2, with interaction', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('Speed in x direction', fontsize=15)
plt.plot(part2_x, part2_v_x)
plt.savefig('Particle2_x_speed.pdf')
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 2, with interaction', fontsize=15)
plt.xlabel('position [y]', fontsize=15)
plt.ylabel('Speed in y direction', fontsize=15)
plt.plot(part2_y, part2_v_y)
plt.savefig('Particle2_y_speed.pdf')
plt.show()

# %% [markdown]
# ### Without interaction

# %% [markdown]
# Particle 1

# %%
part1_x = []
part1_v_x = []
part1_y = []
part1_v_y = []
for line in open('Particle1_RK4_NO_INTER_speed.txt', 'r'):
    lines = [i for i in line.split()]
    part1_x.append(float(lines[0]))
    part1_v_x.append(float(lines[1]))
    part1_y.append(float(lines[2]))
    part1_v_y.append(float(lines[3]))

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 1, without interaction', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('Speed in x direction', fontsize=15)
plt.plot(part1_x, part1_v_x)
plt.savefig('Particle1_x_speed_NO.pdf')
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 1, without interaction', fontsize=15)
plt.xlabel('position [y]', fontsize=15)
plt.ylabel('Speed in y direction', fontsize=15)
plt.plot(part1_y, part1_v_y)
plt.savefig('Particle1_y_speed_NO.pdf')
plt.show()

# %% [markdown]
# Particle 2

# %%
part2_x = []
part2_v_x = []
part2_y = []
part2_v_y = []
for line in open('Particle2_RK4_NO_INTER_speed.txt', 'r'):
    lines = [i for i in line.split()]
    part2_x.append(float(lines[0]))
    part2_v_x.append(float(lines[1]))
    part2_y.append(float(lines[2]))
    part2_v_y.append(float(lines[3]))

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 2, without interaction', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('Speed in x direction', fontsize=15)
plt.plot(part2_x, part2_v_x)
plt.savefig('Particle2_x_speed_NO.pdf')
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('Particle 2, without interaction', fontsize=15)
plt.xlabel('position [y]', fontsize=15)
plt.ylabel('Speed in y direction', fontsize=15)
plt.plot(part2_y, part2_v_y)
plt.savefig('Particle2_y_speed_NO.pdf')
plt.show()

# %% [markdown]
# ## 3D plot of both particles

# %% [markdown]
# With interaction

# %%
import matplotlib.pyplot as plt

part1_x = []
part1_y = []
part1_z = []
part2_x = []
part2_y = []
part2_z = []
for line in open('Particles_INTER.txt', 'r'):
    lines = [i for i in line.split()]
    part1_x.append(float(lines[0]))
    part1_y.append(float(lines[1]))
    part1_z.append(float(lines[2]))
    part2_x.append(float(lines[3]))
    part2_y.append(float(lines[4]))
    part2_z.append(float(lines[5]))

# %% [markdown]
# Particle 1

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.set_title('Particle 1, 50μs with interaction', fontsize=15);
ax.set_xlabel('Posision [x]', fontsize=15)
ax.set_ylabel('Posision [y]', fontsize=15)
ax.set_zlabel('Posision [z]', fontsize=15)
ax.plot3D(part1_x, part1_y, part1_z, 'gray')
plt.savefig('Particle1_xyz_INT.pdf')

# %% [markdown]
# Particle 2

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.set_title('Particle 2, 50μs with interaction', fontsize=15);
ax.set_xlabel('Posision [x]', fontsize=15)
ax.set_ylabel('Posision [y]', fontsize=15)
ax.set_zlabel('Posision [z]', fontsize=15)
ax.plot3D(part2_x, part2_y, part2_z, 'gray')
plt.savefig('Particle2_xyz_INT.pdf')

# %% [markdown]
# Wothout interaction

# %%
part1_x = []
part1_y = []
part1_z = []
part2_x = []
part2_y = []
part2_z = []
for line in open('Particles_NO_INTER.txt', 'r'):
    lines = [i for i in line.split()]
    part1_x.append(float(lines[0]))
    part1_y.append(float(lines[1]))
    part1_z.append(float(lines[2]))
    part2_x.append(float(lines[3]))
    part2_y.append(float(lines[4]))
    part2_z.append(float(lines[5]))

# %% [markdown]
# Particle 1

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.set_title('Particle 1, 50μs without interaction', fontsize=15);
ax.set_xlabel('Posision [x]', fontsize=15)
ax.set_ylabel('Posision [y]', fontsize=15)
ax.set_zlabel('Posision [z]', fontsize=15)
ax.plot3D(part1_x, part1_y, part1_z, 'gray')
plt.savefig('Particle1_xyz_NO.pdf')

# %% [markdown]
# Particle 2

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.set_title('Particle 2, 50μs without interaction', fontsize=15);
ax.set_xlabel('Posision [x]', fontsize=15)
ax.set_ylabel('Posision [y]', fontsize=15)
ax.set_zlabel('Posision [z]', fontsize=15)
ax.plot3D(part2_x, part2_y, part2_z, 'gray')
plt.savefig('Particle2_xyz_NO.pdf')

# %% [markdown]
# ## Analytical solution one particle

# %%
import matplotlib.pyplot as plt

x_analy = []
y_analy = []
z_analy = []
for line in open('Analytical_SingleParticle.txt', 'r'):
    lines = [i for i in line.split()]
    x_analy.append(float(lines[0]))
    y_analy.append(float(lines[1]))
    z_analy.append(float(lines[2]))

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
plt.savefig('figure.pdf')
ax.plot3D(x_analy, y_analy, z_analy, 'gray')

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.axis('equal')
plt.plot(x_analy, y_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [z]', fontsize=15)
plt.axis('equal')
plt.plot(x_analy, z_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position [x]', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.axis('equal')
plt.plot(y_analy, z_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision [x]', fontsize=15)
plt.plot(x_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision [y]', fontsize=15)
plt.plot(y_analy)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision [z]', fontsize=15)
plt.plot(z_analy)
  
plt.show()

# %% [markdown]
# ## Plotting Analytical Vs. Euler Vs. RK4 with same initial conditions

# %%
import matplotlib.pyplot as plt

x_analy = []
y_analy = []
z_analy = []
for line in open('Analytical_SingleParticle_TEST.txt', 'r'):
    lines = [i for i in line.split()]
    x_analy.append(float(lines[0]))
    y_analy.append(float(lines[1]))
    z_analy.append(float(lines[2]))

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')

ax.plot3D(x_analy, y_analy, z_analy, 'gray')

# %%
import matplotlib.pyplot as plt

x_Eul = []
y_Eul = []
z_Eul = []
for line in open('SingleParticle_n1_TEST_EUL.txt', 'r'):
    lines = [i for i in line.split()]
    x_Eul.append(float(lines[0]))
    y_Eul.append(float(lines[1]))
    z_Eul.append(float(lines[2]))

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')

ax.plot3D(x_Eul, y_Eul, z_Eul, 'gray')

# %%
import matplotlib.pyplot as plt

x_RK4 = []
y_RK4 = []
z_RK4 = []
for line in open('SingleParticle_n1_TEST_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    x_RK4.append(float(lines[0]))
    y_RK4.append(float(lines[1]))
    z_RK4.append(float(lines[2]))

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')

ax.plot3D(x_RK4, y_RK4, z_RK4, 'gray')

# %%
plt.plot(x_analy)

# %%
plt.plot(y_analy)

# %%
plt.plot(z_analy)

# %%
plt.plot(x_Eul)

# %%
plt.plot(y_Eul)

# %%
plt.plot(z_Eul)

# %%
plt.plot(x_RK4)

# %%
plt.plot(y_RK4)

# %%
plt.plot(z_RK4)

# %% [markdown]
# ## Relative error

# %% [markdown]
# ### n1

# %%
import matplotlib.pyplot as plt

x_n1 = []
y_n1 = []
z_n1 = []
for line in open('Rel_error_n1.txt', 'r'):
    lines = [i for i in line.split()]
    x_n1.append(float(lines[0]))
    y_n1.append(float(lines[1]))
    z_n1.append(float(lines[2]))

# %%
n2 = np.linspace(0.0, 50.0, num=3999)

plt.plot(n2, np.log(x_n1))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/2129170009.py:3: RuntimeWarning: invalid value encountered in log
#   plt.plot(n2, np.log(x_n1))

# %%
plt.plot(np.log(y_n1))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/3519011629.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(y_n1))

# %%
plt.plot(np.log(z_n1))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/1241336749.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(z_n1))

# %% [markdown]
# ### n2

# %%
import matplotlib.pyplot as plt

x_n2 = []
y_n2 = []
z_n2 = []
for line in open('Rel_error_n2.txt', 'r'):
    lines = [i for i in line.split()]
    x_n2.append(float(lines[0]))
    y_n2.append(float(lines[1]))
    z_n2.append(float(lines[2]))

# %%
n2 = np.linspace(0.0, 50.0, num=7999)
plt.plot(n2, np.log(x_n2))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/1568272663.py:2: RuntimeWarning: invalid value encountered in log
#   plt.plot(n2, np.log(x_n2))

# %%
plt.plot(np.log(y_n2))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/2698165694.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(y_n2))

# %%
plt.plot(np.log(z_n2))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/1690950112.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(z_n2))
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/1690950112.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(z_n2))

# %%
import matplotlib.pyplot as plt

x_n3 = []
y_n3 = []
z_n3 = []
for line in open('Rel_error_n3.txt', 'r'):
    lines = [i for i in line.split()]
    x_n3.append(float(lines[0]))
    y_n3.append(float(lines[1]))
    z_n3.append(float(lines[2]))

# %%
plt.plot(np.log(x_n3))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/2890207409.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(x_n3))
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/2890207409.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(x_n3))

# %%
plt.plot(np.log(y_n3))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/4199257217.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(y_n3))

# %%
plt.plot(np.log(z_n3))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/3966753690.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(z_n3))
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/3966753690.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(z_n3))

# %%
import matplotlib.pyplot as plt

x_n4 = []
y_n4 = []
z_n4 = []
for line in open('Rel_error_n4.txt', 'r'):
    lines = [i for i in line.split()]
    x_n4.append(float(lines[0]))
    y_n4.append(float(lines[1]))
    z_n4.append(float(lines[2]))

# %%
plt.plot(np.log(x_n4))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/1410461039.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(x_n4))
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/1410461039.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(x_n4))

# %%
plt.plot(np.log(y_n4))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/4013140287.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(y_n4))

# %%
plt.plot(np.log(z_n4))
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/2693589907.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(z_n4))
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_23345/2693589907.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(z_n4))

# %% [markdown]
# Ploted together

# %%
import matplotlib.pyplot as plt
import numpy as np

n1 = np.linspace(0.0, 50.0, num=3999)
n2 = np.linspace(0.0, 50.0, num=7999)
n3 = np.linspace(0.0, 50.0, num=15999)
n4 = np.linspace(0.0, 50.0, num=31999)

fig = plt.figure(figsize=(10, 8))
plt.title('Absolute error for different timesteps [x]', fontsize=15)
plt.plot(n1, np.log(x_n1), label = "n1")
plt.plot(n2, np.log(x_n2), label = "n2")
plt.plot(n3, np.log(x_n3), label = "n3")
plt.plot(n4, np.log(x_n4), label = "n4")
plt.legend()
plt.savefig('AbsErrorX.pdf')
plt.show()
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/2605363765.py:11: RuntimeWarning: invalid value encountered in log
#   plt.plot(n1, np.log(x_n1), label = "n1")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/2605363765.py:12: RuntimeWarning: invalid value encountered in log
#   plt.plot(n2, np.log(x_n2), label = "n2")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/2605363765.py:13: RuntimeWarning: divide by zero encountered in log
#   plt.plot(n3, np.log(x_n3), label = "n3")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/2605363765.py:13: RuntimeWarning: invalid value encountered in log
#   plt.plot(n3, np.log(x_n3), label = "n3")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/2605363765.py:14: RuntimeWarning: divide by zero encountered in log
#   plt.plot(n4, np.log(x_n4), label = "n4")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/2605363765.py:14: RuntimeWarning: invalid value encountered in log
#   plt.plot(n4, np.log(x_n4), label = "n4")

# %%
n1 = np.linspace(0.0, 50.0, num=3999)
n2 = np.linspace(0.0, 50.0, num=7999)
n3 = np.linspace(0.0, 50.0, num=15999)
n4 = np.linspace(0.0, 50.0, num=31999)

fig = plt.figure(figsize=(10, 8))
plt.title('Absolute error for different timesteps [y]', fontsize=15)
plt.plot(n1, np.log(y_n1), label = "n1")
plt.plot(n2, np.log(y_n2), label = "n2")
plt.plot(n3, np.log(y_n3), label = "n3")
plt.plot(n4, np.log(y_n4), label = "n4")
plt.legend()
plt.savefig('AbsErrorY.pdf')
plt.show()
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/461800979.py:8: RuntimeWarning: invalid value encountered in log
#   plt.plot(n1, np.log(y_n1), label = "n1")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/461800979.py:9: RuntimeWarning: invalid value encountered in log
#   plt.plot(n2, np.log(y_n2), label = "n2")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/461800979.py:10: RuntimeWarning: invalid value encountered in log
#   plt.plot(n3, np.log(y_n3), label = "n3")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/461800979.py:11: RuntimeWarning: invalid value encountered in log
#   plt.plot(n4, np.log(y_n4), label = "n4")

# %%
n1 = np.linspace(0.0, 50.0, num=3999)
n2 = np.linspace(0.0, 50.0, num=7999)
n3 = np.linspace(0.0, 50.0, num=15999)
n4 = np.linspace(0.0, 50.0, num=31999)

fig = plt.figure(figsize=(10, 8))
plt.title('Absolute error for different timesteps [z]', fontsize=15)
plt.plot(n1, np.log(z_n1), label = "n1")
plt.plot(n2, np.log(z_n2), label = "n2")
plt.plot(n3, np.log(z_n3), label = "n3")
plt.plot(n4, np.log(z_n4), label = "n4")
plt.legend()
plt.savefig('AbsErrorZ.pdf')
plt.show()
# Out:
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/3598450932.py:8: RuntimeWarning: invalid value encountered in log
#   plt.plot(n1, np.log(z_n1), label = "n1")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/3598450932.py:9: RuntimeWarning: divide by zero encountered in log
#   plt.plot(n2, np.log(z_n2), label = "n2")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/3598450932.py:9: RuntimeWarning: invalid value encountered in log
#   plt.plot(n2, np.log(z_n2), label = "n2")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/3598450932.py:10: RuntimeWarning: divide by zero encountered in log
#   plt.plot(n3, np.log(z_n3), label = "n3")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/3598450932.py:10: RuntimeWarning: invalid value encountered in log
#   plt.plot(n3, np.log(z_n3), label = "n3")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/3598450932.py:11: RuntimeWarning: divide by zero encountered in log
#   plt.plot(n4, np.log(z_n4), label = "n4")
# /var/folders/g8/mf2s8g352jqg1_cpwxd_z6dc0000gn/T/ipykernel_24080/3598450932.py:11: RuntimeWarning: invalid value encountered in log
#   plt.plot(n4, np.log(z_n4), label = "n4")

# %% [markdown]
# # Task 9

# %%
import matplotlib.pyplot as plt

f0_1 = []
p0_1 = []
for line in open('Time_dep_V0_0_1.txt', 'r'):
    lines = [i for i in line.split()]
    f0_1.append(float(lines[0]))
    p0_1.append(float(lines[1]))

# %%
import matplotlib.pyplot as plt

f0_4 = []
p0_4 = []
for line in open('Time_dep_V0_0_4.txt', 'r'):
    lines = [i for i in line.split()]
    f0_4.append(float(lines[0]))
    p0_4.append(float(lines[1]))

# %%
import matplotlib.pyplot as plt

f0_7 = []
p0_7 = []
for line in open('Time_dep_V0_0_7.txt', 'r'):
    lines = [i for i in line.split()]
    f0_7.append(float(lines[0]))
    p0_7.append(float(lines[1]))

# %%
fig = plt.figure(figsize=(12, 10))
#plt.title('F', fontsize=15)
plt.xlabel('Period', fontsize=15)
plt.ylabel('Fraction of total particles left', fontsize=15)
plt.plot(p0_1, f0_1, label = "0.1")
plt.plot(p0_4, f0_4, label = "0.4")
plt.plot(p0_7, f0_7, label = "0.7")
plt.legend()
plt.show()
