# %% [markdown]
# # Project 3

# %% [markdown]
# ### Task 8

# %% [markdown]
# ## Euler in z direction

# %%
import matplotlib.pyplot as plt
  
x = []
y = []
for line in open('Particle_z.txt', 'r'):
    lines = [i for i in line.split()]
    x.append(float(lines[0]))
    y.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision_z', fontsize=15)
plt.plot(x)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posision_z', fontsize=15)
plt.plot(y)
  
plt.show()

# %% [markdown]
# ## RK4 in z direction

# %%
import matplotlib.pyplot as plt
  
xRK = []
yRK = []
for line in open('Particle_z_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    xRK.append(float(lines[0]))
    yRK.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posisjon_z', fontsize=15)
plt.plot(xRK)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posisjon_z', fontsize=15)
plt.plot(yRK)
  
plt.show()

# %%
Fx = [3.2126e+06,  5.5525e+06, 7.7712e+06]

plt.plot(Fx)

# %%
Fy = [3.9224e+05, -7.2551e+05,  -4.8783e+06]
plt.plot(Fy)

# %%
plt.plot(Fx, Fy)

# %%
import matplotlib.pyplot as plt
  
x_eul = []
y_eul = []
for line in open('Particle_x_Euler.txt', 'r'):
    lines = [i for i in line.split()]
    x_eul.append(float(lines[0]))
    y_eul.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('time', fontsize=15)
plt.ylabel('posisjon_x', fontsize=15)
plt.plot(x_eul)
  
plt.show()

# %%
plt.plot(y_eul)

# %% [markdown]
# ## Euler in xy-plane

# %%
import matplotlib.pyplot as plt
  
x_eul1 = []
x_eul2 = []
for line in open('Particle_x_Euler_REL.txt', 'r'):
    lines = [i for i in line.split()]
    x_eul1.append(float(lines[0]))
    x_eul2.append(float(lines[1]))
    
y_eul1 = []
y_eul2 = []
for line in open('Particle_y_Euler_REL.txt', 'r'):
    lines = [i for i in line.split()]
    y_eul1.append(float(lines[0]))
    y_eul2.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('position_x', fontsize=15)
plt.ylabel('posisjon_y', fontsize=15)
plt.axis('equal')
plt.plot(y_eul1)

# %%
import matplotlib.pyplot as plt
  
x_eul1 = []
x_eul2 = []
for line in open('Particle_x_Euler_REL.txt', 'r'):
    lines = [i for i in line.split()]
    x_eul1.append(float(lines[0]))
    x_eul2.append(float(lines[1]))
    
y_eul1 = []
y_eul2 = []
for line in open('Particle_y_Euler_REL.txt', 'r'):
    lines = [i for i in line.split()]
    y_eul1.append(float(lines[0]))
    y_eul2.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 2', fontsize=15)
plt.xlabel('position_x', fontsize=15)
plt.ylabel('posisjon_y', fontsize=15)
plt.axis('equal')
plt.plot(x_eul1)

# %% [markdown]
# ## RK4 in the xy plane

# %%
import matplotlib.pyplot as plt
  
x_eul1 = []
x_eul2 = []
for line in open('Particle_x_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    x_eul1.append(float(lines[0]))
    x_eul2.append(float(lines[1]))
    
y_eul1 = []
y_eul2 = []
for line in open('Particle_y_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    y_eul1.append(float(lines[0]))
    y_eul2.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('position_x', fontsize=15)
plt.ylabel('posisjon_y', fontsize=15)
plt.plot(x_eul1, y_eul1)

# %%
import matplotlib.pyplot as plt
  
x_eul1 = []
x_eul2 = []
for line in open('Particle_x_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    x_eul1.append(float(lines[0]))
    x_eul2.append(float(lines[1]))
    
y_eul1 = []
y_eul2 = []
for line in open('Particle_y_RK4.txt', 'r'):
    lines = [i for i in line.split()]
    y_eul1.append(float(lines[0]))
    y_eul2.append(float(lines[1]))
      
fig = plt.figure()
plt.title('Particle 1', fontsize=15)
plt.xlabel('position_x', fontsize=15)
plt.ylabel('posisjon_y', fontsize=15)
plt.plot(x_eul2, y_eul2)
